# %% [markdown]
# # Lab 3: Detoxifying AI-generated summaries to produce clearer and more professional outputs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Imports

# %%
from transformers import BartForConditionalGeneration, BartTokenizer
import torch
import pandas as pd
import textwrap

# %% [markdown]
# - **BartForConditionalGeneration**: This is the pre-trained BART model specifically for text generation tasks like summarization. In our case, we will use this to generate summaries for case law documents.
#
# - **BartTokenizer**: The tokenizer is responsible for encoding and decoding text to and from tokens, which are the format required by the BART model. It helps prepare the input text for processing by the model and decodes the output back into readable text.
#
# - **torch**: PyTorch is the deep learning framework that the BART model is built on. We import `torch` to handle tensors and manage model training and inference.
#
# - **pandas**: Pandas is used for data manipulation and analysis. It allows us to load, process, and handle the dataset, specifically the case law text and summaries.
#
# - **textwrap**: This library provides functions for wrapping and formatting text, making it more readable. It can help us in neatly formatting text outputs, especially when displaying large chunks of generated text.

# %% [markdown]
# ### Loading Fine-Tuned BART Model and Tokenizer

# %%
model_dir = "/content/drive/MyDrive/fine_tuned_bart_best"
model = BartForConditionalGeneration.from_pretrained(model_dir)
tokenizer = BartTokenizer.from_pretrained(model_dir)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/bart/configuration_bart.py:176: UserWarning: Please make sure the config includes `forced_bos_token_id=0` in future versions. The config can simply be saved and uploaded again to be fixed.
#   warnings.warn(

# %% [markdown]
# - **model_dir**: This variable holds the path to the directory where the fine-tuned BART model is stored in Google Drive. The path is specified as `"/content/drive/MyDrive/fine_tuned_bart_best"`, indicating the best version of the fine-tuned model saved during training.
#
# - **model = BartForConditionalGeneration.from_pretrained(model_dir)**:
#   This line loads the fine-tuned BART model from the specified `model_dir`. The model has already been trained on case law data, so it’s ready for inference, such as summarizing new documents. The `from_pretrained()` function is used to load both the architecture and the weights of the model.
#
# - **tokenizer = BartTokenizer.from_pretrained(model_dir)**:
#   This line loads the tokenizer from the same directory as the fine-tuned model. Since the tokenizer was likely customized during the fine-tuning process, it's crucial to load the same tokenizer used during training. This ensures that the text encoding and decoding are consistent during both training and inference.

# %%
df = pd.read_csv("/content/drive/MyDrive/cleaned_cases_num_two.csv")
fdf = pd.read_csv("/content/drive/MyDrive/legal_cases.csv")

# %% [markdown]
# ### Data Cleaning and Splitting for Summarization
#
# In this section, the dataset is cleaned and then split into smaller chunks of text to ensure compatibility with the model’s input length constraints. Here's a step-by-step breakdown of the process:

# %%
df['text_length'] = df['cleaned_text'].apply(lambda x: len(x.split()))
print(df['text_length'].describe())  # Get a summary of text lengths
# Out:
# count       50.000000
# mean      7692.240000
# std       8526.647499
# min        315.000000
# 25%       1891.500000
# 50%       5943.500000
# 75%      10654.250000
# max      52823.000000
# Name: text_length, dtype: float64

# %%
df['cleaned_text'] = df['cleaned_text'].astype(str)
print(df.dtypes)
# Out:
# cleaned_text    object
# text_length      int64
# dtype: object

# %%
df['cleaned_text'] = df['cleaned_text'].str.replace('[^\w\s]', '', regex=True)
df['cleaned_text'] = df['cleaned_text'].str.strip()

# %%
def split_text(text, max_length=1024):
    words = text.split()
    return [' '.join(words[i:i+max_length]) for i in range(0, len(words), max_length)]


df['split_texts'] = df['cleaned_text'].apply(split_text)
split_rows = []
for _, row in df.iterrows():
    case_law_chunks = split_text(row['cleaned_text'], max_length=1024)
    for chunk in case_law_chunks:
        split_rows.append({
            'cleaned_text': chunk,
        })
        
split_df = pd.DataFrame(split_rows)
print(split_df.head())
# Out:
#                                         cleaned_text
# 0  Judgments and decisions from 2001 onwards 2025...
# 1  phase of the trial an oral hearing expected to...
# 2  nonEuropean Union states with modifications to...
# 3  trial process or the end of any sentence The c...
# 4  to the category 1 territory in which the warra...

# %% [markdown]
# 1. **Text Length Calculation**:
#    - `df['text_length'] = df['cleaned_text'].apply(lambda x: len(x.split()))`:
#      This line calculates the number of words in each `cleaned_text` entry and stores the result in a new column `text_length`.
#    - `print(df['text_length'].describe())`:
#      Outputs a summary of the text lengths, which helps in understanding the distribution of text sizes across the dataset.
#
# 2. **Text Cleaning**:
#    - `df['cleaned_text'] = df['cleaned_text'].astype(str)`:
#      Converts the `cleaned_text` column to a string data type, ensuring all entries are processed correctly.
#    - `print(df.dtypes)`:
#      Outputs the data types of the columns to confirm that the `cleaned_text` column has been correctly converted.
#    - `df['cleaned_text'].str.replace('[^\w\s]', '', regex=True)`:
#      Removes any non-alphanumeric characters from the `cleaned_text` using regular expressions. This step ensures the text is cleaner and ready for tokenization.
#    - `df['cleaned_text'].str.strip()`:
#      Strips any leading or trailing whitespace from the text.
#
# 3. **Text Splitting**:
#    - `split_text(text, max_length=1024)`:
#      This function splits the cleaned text into smaller chunks, with each chunk containing up to `max_length=1024` words. This step is essential because models like BART have a maximum input length, and splitting the text ensures the input size is manageable.
#    - `df['split_texts'] = df['cleaned_text'].apply(split_text)`:
#      Applies the `split_text` function to each entry in the `cleaned_text` column, storing the result in a new column called `split_texts`. Each document is now represented as multiple chunks of text.
#
# 4. **Creating a New DataFrame for Split Texts**:
#    - The code then iterates through each row of the dataframe, splits the cleaned text into chunks using the `split_text` function, and stores the chunks in a new list `split_rows`.
#    - Each chunk is stored in a dictionary, which is appended to the `split_rows` list.
#
# 5. **New DataFrame with Split Texts**:
#    - `split_df = pd.DataFrame(split_rows)`:
#      A new dataframe `split_df` is created from the `split_rows` list. This dataframe contains the split chunks of text, which are now ready to be processed by the model for summarization.
#
# 6. **Output Preview**:
#    - `print(split_df.head())`:
#      Displays the first few rows of the new `split_df` dataframe to verify the splitting process.
#
# By cleaning and splitting the text into smaller chunks, we ensure that the input to the model is within its token limit (1024 tokens), allowing for more effective summarization.

# %% [markdown]
# ### Generating and Printing Summaries for Case Law
#
# In this section, we test the summarization model by generating summaries for 40 selected case law texts from the dataset. The aim is to evaluate the performance of the summarization model across different chunks of case law data. Here's the breakdown of the code:

# %%
def generate_summary(input_text):
    inputs = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(inputs['input_ids'], num_beams=4, max_length=500, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
def summarize_long_text(text, chunk_size=1024):
       chunks = textwrap.wrap(text, width=chunk_size)
       summaries = [generate_summary(chunk) for chunk in chunks]
       return " ".join(summaries)

# %%
def print_selected_summaries(split_df, num_summaries=40):
    total_summaries = len(split_df)
    selected_indices = [0, total_summaries - 1] # First and Last
    increment = total_summaries // (num_summaries -1 )
    selected_indices.extend(range(increment, total_summaries, increment)[:num_summaries - 2])
    selected_indices = sorted(list(set(selected_indices)))

    for index in selected_indices:
        if index < len(split_df):
            input_text = split_df.loc[index, 'cleaned_text']
            output = summarize_long_text(input_text)
            wrapped_text = textwrap.fill(output, width=80)
            print(f"Summary {index + 1}:", wrapped_text)
            print("--------------------------------------------------------------------------------\n")

# %% [markdown]
# 1. **`generate_summary` Function**:
#    - This function takes an `input_text` and generates a summary using the trained BART model.
#    - The `tokenizer` encodes the input text, converting it into tensors with a maximum length of 1024 tokens, truncating the text if necessary.
#    - The `model.generate` method produces the summary, using beam search with 4 beams to improve the quality of the generated output.
#    - The resulting summary is then decoded back into text using `tokenizer.decode`, with special tokens skipped to ensure a clean summary output.
#
# 2. **`summarize_long_text` Function**:
#    - Case law texts may exceed the model’s input token limit of 1024 tokens. To handle this, `summarize_long_text` splits the input text into smaller chunks using the `textwrap.wrap` method, where each chunk is no larger than `chunk_size=1024`.
#    - The `generate_summary` function is applied to each chunk to generate summaries for each part of the text.
#    - All the chunk summaries are then combined and returned as a single, summarized text.
#
# 3. **`print_selected_summaries` Function**:
#    - This function selects and prints 40 summaries from the `split_df` dataset, which contains cleaned and split case law texts.
#    - It first calculates how many summaries to print by selecting the first and last entries, and then evenly distributing the remaining summaries from the middle of the dataset.
#    - For each selected case law entry, the function calls `summarize_long_text` to generate the summary and formats the output using `textwrap.fill` for better readability.
#    - Finally, the summaries are printed with a visual separator between each summary to easily differentiate them.
#
# 4. **Evaluation of Summarization**:
#    - By printing 40 summaries, we are able to visually inspect the quality of the model's performance. Since the model wasn't deeply trained, we expect some variability in the quality of the generated summaries.
#    - Some of the summarizations may be accurate and coherent, while others may lack the necessary context or clarity.
#    - This is an initial test of the summarization model, and further fine-tuning and training would likely improve the results.
#
# 5. **Testing New Case Law Summaries**:
#    - This code tests the model on newer case law documents. The 40 summaries printed serve as a test case to evaluate the effectiveness of the summarizer, and it provides insights into areas where the model performs well and where improvements are needed.

# %%
print_selected_summaries(split_df, num_summaries=40)
# Out:
# Summary 1:  ur. The actual trial in Aruba is estimated to last two days. The respondent
# proposes that if the appellant is acquitted he will be released in St Maarten,
# and that if he is convicted he will serve his sentence in a Dutch prison. The
# appellant says these proceedings are an abuse of process. inas. Appellant
# appealed against extradition to a territory where extradition is illegal. Appeal
# was refused. . The appellant is a national of St Kitts and Nevis, the respondent
# is a national of St Kitts and Nevis. The respondent alleges that the appellant
# shot Mr Amador Jones six times near a snack bar in St Maarten on 16 April 2011,
# and that Mr Jones died of his wounds the next day. The killing is said by the
# prosecuting authorities to have occurred in the context of a feud about the
# trafficking of cocaine. inas. The appellant, Mr Meagher. ur in St Maarten. The
# appeal relates to an appeal brought under section 57 of the European Convention
# on Human Rights. The appeal is Dismissed.
# --------------------------------------------------------------------------------
#
# Summary 11: . The court is concerned with the welfare of a boy called C1 (Igor Kolosov) who
# is now 12 months old. C1 is the subject of proceedings brought by Sheffield City
# Council which has been represented at this hearing by Mr Pallo. The original
# version of this judgment included the names of the child, parents, other family
# members and all professionals involved with the family, and specific dates were
# identified. This published version has been altered to preserve the privacy and
# anonymity of the family concerned. inas. Case Nos: 202400786 B2, 202400922 B2.
# The court is concerned with the welfare of the children. inas. The court found
# that these breaches have put the children at risk of harm.  ur is the subject of
# proceedings brought by Sheffield City Council. The court is concerned with the
# welfare of a boy called C1 who is now 12 months old. The boy is the subject of
# proceedings brought by Sheffield City Council which has been represented at this
# hearing by Mr Pallo. inaurism. Case Nos: 2024-2020, 2024-2020 and 2024-2020.
# --------------------------------------------------------------------------------
#
# Summary 21: ilitus. The Judge had the power to make a non-molestation order. The fact that a
# penal notice was attached to the child arrangements order which prevented the
# Father from having face to face contact with his children did not preclude the
# making of a non-molestation order to the same effect. inas. There had been no
# application for a non-molested. The court. inas. The court heard oral evidence
# from the father of the children. The court heard oral evidence from the father
# of the children. urtis v Director of Public Prosecution. Case Nos: 202400786 B2,
# 202400922 B2; 202400380 B2 and 202401872 B2. The parties seek declarations in
# respect of a non-molestation order which was made in the Crown Court by consent.
# inaurism. Court was contemplating making an NMO. The Father knew that a power of
# arrest was being considered. inas. The non-molestation order (‘the NMO’) was an
# exceptional order and I have carefully considered whether it was necessary. The
# NMO was an exceptional order and I am satisfied that the Judge was entitled to.
# --------------------------------------------------------------------------------
#
# Summary 31: inas. Case Nos: 202400786 B2, 202400922. Case Nos: 202400786 B2, 202400972.
# inas.  inas. The Defendants blamed Mr Rahman for what had taken place. The
# Claimants said that Mr Rahman had actively encouraged them to go to Dubai and
# that Mr Rahman had lied about the contractual arrangements that would be put in
# place. ure (‘Dare’) v Rex & Onyx Ltd. (‘Dare’) Ltd. The Defendants were clearly
# disappointed that the move to Dubai had not taken place. They blamed Mr Rahman
# for it. ine. The Tribunal heard oral evidence from the witnesses, and received
# detailed skeleton arguments and extensive oral submissions from counsel, Mr
# Carey and Mr Meagher. There were a number of preliminary issues, including an
# application by Mr Meagher to strike out the appeal brought by Mr Rahman dated 4
# October 2023 and an objection by Mr Meagher dated 5 October 2023.
# --------------------------------------------------------------------------------
#
# Summary 41: ine onyx@Onyx.com is a firm of solicitors. We are asked to determine a
# preliminary issue of contract validity under section 57 of the European
# Convention on Human Rights. The original version of this judgment included the
# names of the individuals involved, and specific dates, and specific dates were
# identified. This published version has been altered to preserve the privacy and
# anonymity of the individual concerned. inas. ition Ltd (’D2) v Director of
# Public Proprietor’ (‘D2’) Mr Beckwith.  inas. ine company D2 Global by Nature
# Ltd (‘D2’) was dissolved on 20 April 2024. The company was dissolved after a
# dispute with its former employee, Mr Dare, over contract terms of service (‘the
# D2 contract’). Mr Dare’s contract with D2 was terminated on 21 April 2024.
# --------------------------------------------------------------------------------
#
# Summary 51: ur. Case Nos: 2024/2024/00362/00363. Case reference: Case Number:
# 2024/00363/00363. Case reference: 2024/00363/00363/00363. inas. The parties
# submitted their Request for Arbitration on 20 April 2022. The claim relates to
# the participation of the Second to Sixth Defendants (‘D2’) and to the strike out
# of claims in contract, under articles 3 and 8 of the European Convention on
# Human Rights.  ineurope. Case Nos: 2024-2024-2024, 2024-2025, 2024-2025 and
# 2024-2025. The claim relates to the participation of a person called D2 who was
# suspended for six weeks after a Medical Practitioner’s Tribunal for England
# (‘D2’). The claimant, D2, was suspended for six weeks after a Medical
# Practitioner’s Tribunal for England (‘D2’)  ists.out to see the Dubai office
# that would be great. D2 also messaged Mr Kayaam after the meeting to say Really
# great to catch up with the team.
# --------------------------------------------------------------------------------
#
# Summary 61: inautility Ltd (‘the Defendants’) is a family firm, of which Mr James Goulding
# is the managing director. The Defendants claim damages for negligence or
# compensation for breach of contract, under the Consumer Rights Act 2010. Mr
# Goulding claims substantial damages based on loss of anticipated earnings,
# together with general damages. . The Judgment was handed down remotely at
# 10.30am on 14 January 2025 by circulation to the parties or their
# representatives by e-mail and by release to the National Archives. . The
# Defendants denied that they were fiduciaries. inas. The judgment was handed down
# remotely at 10.30am on 14 January 2025 by circulation to the parties or their
# representatives by e-mail and by release to the National Archives. . Case Nos:
# 202400786 B2, 202400922 B2 and 202400380 B2. The parties sought declarations in
# respect of sums said to be due to them, and for payment of the said sums. The
# Defendants denied any liability to the Claimants.  ine. The parties were deemed
# to have meant to have meant to enter into a valid agreement. Zender that is the
# construction which the Court should prefer.
# --------------------------------------------------------------------------------
#
# Summary 71: inas. Case Nos: 2024-2020. Case Number: 2024-2020. urinary partner (‘Dare’)
# applied for an order that Mr Dare must use all reasonable endeavours to ensure
# that his employee (’Dare’) was paid for time off due to illness or injury due to
# suspension due to illness. Dare appealed against the decision of the Tribunal.
# hammers (‘D1’) appealed against a decision of the Tribunal dated 4 October 2023
# Ref. ICJ 37 (Employment Tribunal) 21 October 2023. The appeal relates to an
# appeal brought under section 57 of the Freedom of Information Act 2000 (‘FOIA’)
# against the decision notice of the Tribunal dated 13 December 2023 Ref. ICJ 37
# (‘FOIA’) which stated that an employee is not entitled to be paid for time off
# for illness if the illness is caused by or exacerbated by absence from work due
# to absence from work. The claimant therefore contends that she is entitled to be
# paid for time off for sickness. ur. The contract of employment provided that an
# employee could be required to undergo a medical examination by a medical
# practitioner appointed by the employer at the reasonable request of the
# employer. Mr Solomon KC argued that the direction to attend an occupational
# health referral was not reasonable. .one month later dismissed himone month
# later dismissed him. itioner (‘D1’) appealed against decision of 31 July 2023 by
# the Tribunal. Case Nos: 202400786 B2, 202400922 B2; 202400380 B2 and 202401872
# B2. The appeal is Dismissed.
# --------------------------------------------------------------------------------
#
# Summary 81: urety Ltd (‘the Claimants’) against the decision maker’s decision to strike out
# an appeal brought under section 57 of the Freedom of Information Act 2000
# (“FOIA”) against the decision notice of the Defendant’s decision maker to seek
# an order striking out the appeal dated 12 December 2023 Ref. IC-244791 – Z9Q15
# (‘the DN’) which is a matter of public record. . The claim is essentially for
# professional negligence and misconduct between 2008 to 2010 in the conduct of
# the administrations of a number of insolvent companies. The value of claim. .
# The claim relates to the participation of the Second to Sixth Defendants (‘the
# Individuals’) and to the strike out claims in contract, under the Consumer
# Rights Act 2010 (“the ‘PLT’). The claim alleges disability discrimination and
# victimisation of various kinds under the Equality Act 2010. Mr Meagher claims
# substantial damages based on loss of anticipated earnings, together with general
# damages. inas. The judgment was handed down remotely at 10.30am on [date] by
# circulation to the parties or their representatives by e-mail and by release to
# National Archives.
# --------------------------------------------------------------------------------
#
# Summary 91: inas. . The claimant, Mr Howells, says that he is the subject of proceedings
# brought by Sheffield City Council which has been represented at this hearing by
# Mr Howells. The claimant says that he is the subject of proceedings brought by
# Sheffield City Council which has been represented at this hearing by Mr Howells'
# former partner, Ms Furhmann. inas. Case Nos: 202400786786 B2, 202400922 B2;
# 202400380 B2 and 202401872 B2. The claimant, Mr Khan and Mr Khan's case. inautex
# Ltd is the registered freehold proprietor of Northwood Hall, Hornsey Lane, N6
# 5PG, London, EC4A 1NL. The claimant, Mr Howells, says that in August 2013 a hard
# drive containing the private key to his Bitcoin was deposited in error at
# Docksway Landfill Site, Newport. By his claim issued on 17 May 2024 he contends
# that he is the owner of the hard drive and of everything on it. The defendant
# has applied for an order striking out the claim. .investigation had autodelete
# enabled shortly after they were created. The only messages which were preserved
# beyond 1 day or 1 week as applicable were those few which had been sent at the
# start of the thread before the autodelete function was enabled. . The claimant
# contends that actual deletion took place of at least four Group Chats and one
# on-line message. The suppression of evidence point can only be based on the
# deletion of the four Autodeleted Threads, the possible deletion of some onetoone
# communications between the journalists, and the failed attempt to delete the
# Last Day and Final threads.
# --------------------------------------------------------------------------------
#
# Summary 101: . The claimant is the widow of the late Stephen George Packer, who died from
# cancer on 5 July 2022. The estate agents Mr Packer says that he is the executor
# of the will of his late wife, the late Mrs Packer. She says that he made two
# wills before he died, one in 2017 and one in 2022, by which he was appointed
# executor, and which cannot now be found. The claimant now seeks an order that
# letters of administration be issued to her. . The claimant is the widow of the
# late Stephen George Packer, who died from cancer on 5 July 2022. The defendant
# is the sister of the deceased. She says that he made two wills before he died,
# one in 2017 and one in 2022, by which was never served to her. The claimant now
# seeks an order that letters of administration be issued to her. . The claimants
# own delay in preparing its case is therefore not a good reason for an extension
# of time. It is important to consider whether the limitation period has or may
# have expired since the commencement of proceedings. . The claimant is the widow
# of the late Stephen George Packer, who died from cancer on 5 July 2022. The
# defendant is the sister of the deceased. She says that he made two wills before
# he died. urt. Case Nos: 202400786786 B2, 202400922 B2, 202400922 B2 and
# 202401872 B2. The claimant is the widow of the late Stephen George Packer.
# .committed within the jurisdiction. The relevant principles applicable to
# service out under CPR Part 6 were set out by Lloyd LJ in VTB Capital v Nutritek
# (‘VTB’).
# --------------------------------------------------------------------------------
#
# Summary 111: inas. Case Nos: 202400786786 B2, 202400922 B2, 202400923 B2 and 202401872 B2.
# The claim relates to the loss of a total of £1,246,600,000 plus interest. The
# claim is essentially for professional negligence and misconduct between 2008 to
# 2010. itioner claims against Valeo. Case Nos: 202400786 B2, 202400922 B2;
# 202400380 B2 and 202401872 B2. The claim concerns whether a total of
# £1,206,600,000 was owed to the claimant by way of payment of compensation for
# the loss of output tax overdeclared between 1 October 2016 and 10 March 2020.
# The claim is essentially for professional negligence and misconduct between 2008
# to 2020. inasinas. The claim relates to the participation of the defendants in
# the manufacture, sale and distribution of organic products in the United
# Kingdom. The value of the claim is said to be £1,109,600,000 plus interest.
# inasinasinas. The claim relates to the participation of the Sanden Group in the
# conduct of the administrations of a number of insolvent companies. The value of
# the claim is said to be £1,109,600,000 plus interest. The claim is essentially
# for professional negligence and misconduct between 2008 to 2010 in the conduct
# of the administrations of the companies.  . Case Nos: 2024003900786 B2,
# 202400922 B2, 202400380 B2 and 202401872 B2. The claim is essentially for
# professional negligence and misconduct between 2008 to 2010.
# --------------------------------------------------------------------------------
#
# Summary 121: ilitis. Case Nos: 202400786786 B2, 202400922 B2 and 202400922 B2. The appeal
# relates to the release of a man to HMP Frankland, Norfolk. The claimant, Mr
# Howells, was sentenced to a total of 10 years’ imprisonment for two offences of
# rape of a child, three offences of sexual assault on a child under 13, two
# offences of sexual assault on a child under 13, and two offences of making or
# possessing indecent images of children. . Case Nos: 202400786786786 B2,
# 202400922 B2; 202400380 B2 and 202401872 B2. The appeal relates to the
# participation of the Second to Sixth Defendants (‘the Individuals’) and to the
# confinement of Mr Meagher in segregation units (‘the Cells’) and Mr Meagher in
# general. ine. The Claimant suffers from a mental disorder and is subject to
# segregation due to disability. The Claimants case arises out of the fact that
# she is subject to segregation due to disability and is subject to regular
# surveillance by the authorities. . She poses an exceptionally high risk to
# others including other prisoners. She poses an exceptionally high risk to others
# including other prisoners. inaur Alex Worsman (‘Alex’) against decision of 27
# July 2023. Case Nos: 202400786 B2, 202400922 B2; 202400380 B2 and 202401872 B2.
# The claim concerns whether a letter of attack dated 27 July 2024. . Worsman is
# the subject of proceedings brought by Sheffield City Council which has been
# represented at this hearing by Mr Pallo. The claim concerns whether a letter of
# indemnity (‘the LOI’) is valid and binding. The claim concerns whether a letter
# of indemnity is valid and binding.
# --------------------------------------------------------------------------------
#
# Summary 131: . The Judgment was handed down remotely at 10.30am on 5 February 2025 by
# circulation to the parties or their representatives by e-mail and by release to
# the National Archives. itioner v Director of Public Proprietors – Case Nos:
# 202400786 B2, 202400922 B2 and 202400380 B2. The claim concerns articles
# published on the Defendants Substack and comments posted in response to those
# articles. . The Claimants submitted its Request for Arbitration on 20 April
# 2022. The Claimants submitted its Request on 20 April 2022. The Defendant
# responded on 24 May 2024. . The Claimants submitted their Request for
# Arbitration on 20 April 2022. The claim concerned whether a letter of indemnity
# (‘the LOI’) was valid and binding. The Claimants submitted its Request on 20
# April 2022. . The parties agree that any reader. . Case Nos: BL-202300786 B2,
# CR-202300786 B2, CR-20230091 B2 and CR-20230091 B2. The Claimants case is that
# Publication 41 (‘the Claimant’). The Claimants case is that Publication 41 (‘the
# Claimant’).
# --------------------------------------------------------------------------------
#
# Summary 141: inas. The appeal is Dismissed. No dispute as to the material facts of this case.
# No dispute as to the material facts of this case.
# --------------------------------------------------------------------------------
#
# Summary 151: inas. The court heard oral evidence from the witnesses, and received detailed
# skeleton arguments and extensive oral submissions from counsel, Mr Carey and Mr
# Dean. There were a number of preliminary issues, including an application by the
# claimant to strike out. ina Wigoder v Rex & Ors v Rex & Justice & Justice. Case
# Nos: 202400786 B2, 202400922 B2; 202400380 B2 and 202401872 B2. ur in Malta.
# Case concerned an application for the return of an older teenager, aged 14 and 3
# months, to Malta. Case concerned an application for the return of an older
# teenager, aged 14 and 3 months to Malta. ur. Case Nos: 202400786786 B2,
# 202400922 B2, 202400922 B2 and 202401872 B2. The original version of this
# judgment included the Defendant’s. ilitis. Case Nos: 202400786786 B2, 202400922
# B2 and 202400922 B2. The court. urinary partner. Case Nos: 202400786786 B2,
# 202400922 B3. Case Nos: 202400786 B2, 202400922 B2 and 202400922 B2.
# --------------------------------------------------------------------------------
#
# Summary 161: . The Claimants submitted their Request for Arbitration on 20 April 2022. The
# claim concerned whether a letter of indemnity (‘the LOI’) was valid and binding.
# The Claimants’ case.  companies. Case Nos: 202400786 B2, 202400786 B2, 2024009
# B2. The parties.  companies and individuals. The claim relates to the
# participation of the Second andor Third Defendants (‘the Defendants’) and to the
# strike out of claims in contract, under the Consumer Rights Act 2000 (‘the
# ‘CRA’) and the Consumer Rights Act 2000 (‘the ‘CRA’). The claim alleges that the
# Defendants acted in breach of contract or negligently in breach of contract with
# the Claimants’ rights under the CRA. urinary workers (‘the Claimants’) against
# DJ Houghton & Houghton Ltd (‘the Defendant’). The Claimants claimed damages for
# negligence or compensation for breach of contract, under the Consumer Rights Act
# 2010. They claimed damages for negligence or compensation for breach of contract
# in contract, and for breach of contract under the Consumer Rights Act 2010. The
# Defendant denied any liability to the Claimants.  firm sought to establish that
# its sole director and company secretary were personally or severally liable for
# breach of contract. Case Nos: 202400786 B2, 202400922 B2; 202400380 B2 and
# 202401872 B2. The company sought to establish that its sole director and company
# secretary were liable for breach of contract. . The Claimants submitted their
# Request for Arbitration on 20 April 2022. The claim concerned whether a letter
# of indemnity (‘the LOI’) was valid and binding. The Claimants’ case.
# --------------------------------------------------------------------------------
#
# Summary 171: . The claim relates to the participation of the Second Defendant (‘the Second
# Defendant’) and the First Defendant (‘the Claimant’) ina.com Ltd. confirms that
# it is the subject of proceedings brought by Sheffield City Council. The claim
# relates to the participation of the Second to the First. inas. Case Nos: Case
# Nos: 1, 2, 3. . The Claimants submitted their Request for Arbitration on 20
# April 2022. The claim concerned whether a letter of indemnity (‘the LOI’) was
# valid and binding. The Claimants’ case in the arbitration was that the Claimants
# owed the Claimants’ a total of £1,109,600,000 plus interest. The Claimants’ case
# in the arbitration was that the other board members of WEH had dismissed them
# from their positions at WEH. urgeon claimed damages for negligence or misconduct
# under the Equality Act 2010. Claimed substantial damages based on loss of
# earnings, together with general damages for negligence or misconduct in
# contract, and/or compensation for breach of contract. Claimed substantial
# damages based on loss of earnings, together with general damages. . The Claimant
# was not taking holidays as he was devoting himself to trying to make a success
# of the First Defendants business. He travelled extensively and without a break
# which is how he came to incur many of the expenses for which he claims
# reimbursement.
# --------------------------------------------------------------------------------
#
# Summary 181: urinary expert. Appellant appealed against a decision of the Registrar of
# Approved Practitioners to refuse to grant a second trainee licence. Tribunal
# found that the Registrar was not satisfied that the Appellants request for a
# second licence was justified. urgeon. Appellant applied for a second licence
# before his first licence expired. The Appellant considered a second licence
# would be sufficient for him to book and pass Part 3 test. There is no evidence
# before me which would suggest otherwise. . The appeal is allowed but no further
# trainee licence is granted. The two year statutory time limit for the Appellant
# to pass his Part 3 test is due to expire on 20 March 2025. I therefore decline
# to grant the Appellant any further extension of his trainee licence.
# --------------------------------------------------------------------------------
#
# Summary 191: ur. The appeal is Dismissed. The Appellant appealed against a decision of the
# Respondent to refuse the Appellant’s application for a further third trainee
# driving instructor licence made on 5 July 2024. The appeal was listed for
# determination remotely by CVP on 30 January 2025. inas. The Tribunal heard oral
# evidence from the witnesses, and received detailed skeleton arguments and
# extensive oral submissions from counsel, Mr Carey and Mr Dean. There were a
# number of preliminary issues, including an application by the Respondent to
# strike out the appeal dated 4 October 2023 and an objection by therespondent to
# the Appellant relying on its skeleton argument. urinary licence (‘ADI’) – a
# licence issued to a person who is registered as an Approved Driving Instructor
# (‘the ADI’) – for the purpose of gaining sufficient experience to pass a Part 3
# test to become a fully-qualified Approved Driving Instructor (‘the ADI’) The
# Respondent decided that no evidence of lost practice time had been provided by
# the Appellant that he had received the benefit of two trainee licences covering
# a 12 month period from 22 July 2023 to 21 July 2024 for the purpose of gaining
# sufficient expertise in driving tuition to pass a Part 3 test. urgeon. Appellant
# applied for a third trainee licence before the expiry of his second trainee
# licence. Appellant failed his first attempt at a Part 3 test on 2 September
# 2024. . Appellant appealed against decision of the Tribunal for the Appellant.
# The Tribunal ruled that an ADI applicant could not expect to be granted a
# trainee licence indefinitely. . Appellant applied for a third trainee licence to
# allow him to meet the interests of his existing pupils but was refused.
# Appellant also confirmed that he had failed his second attempt to pass his Part
# 3 test on 4 December 2024 an outcome that he intended to appeal to the
# Magistrates Court.
# --------------------------------------------------------------------------------
#
# Summary 201:  industry giant Vodafone. Case Nos: 202400786786 B2, 202400922 B2 and 202400922
# B2. The parties submitted their claim on 21 October 2024.  firm VM argues that
# it is the subject of proceedings brought by Sheffield City Council which has
# been represented at this hearing by Mr Pallo. VM contends that it is the subject
# of proceedings brought by Sheffield City Council which has been represented at
# this hearing by Mr Pallo. The matter is currently listed for a trial commencing
# on 20 January 2025, with three days set aside for pre-reading.  service provider
# VMVison (’Vison) Ltd (‘VM’) against Which? Ltd. The claim concerns whether VM
# must continue to claim equitable relief and to reinstate the service as it
# primary remedy to the loss of profits caused by the closure of VMVison. inas.
# Case Nos: 202400786786 B2, 202400922 B2 and 202400922 B2. The parties sought
# declarations in respect of services provided by, among other things. ine. Case
# Nos: 202400786 B2, 2024009 B2; 2024003 B2 and 2024018 B2. The claim is
# essentially for professional negligence and misconduct between 2008 to 2010 in
# the conduct of the administrations of a number of insolvent companies. The value
# of the claim was said to be £1,206,600,000 plus interest. . Case Nos: 202400786
# B2, 202400922 B2; 202400380 B2 and 202401872 B2. The claimants submitted to the
# Claimants.
# --------------------------------------------------------------------------------
#
# Summary 211: urgeon. The registrant was suspended for five months after a Medical
# Practitioners Tribunal (‘the MC’) found that his fitness to practise was
# impaired and directed a 5-month suspension with review and also ordered
# immediate suspension. The registrant appealed against both the original
# direction and the subsequent review. Morris J held that the registrant’s fitness
# to practise was impaired and directed a 5-month suspension with review and also
# ordered immediate suspension. . The appeal relates to the participation of the
# Second to Sixth Defendants (‘the Individuals’) and to the suspension of the
# Second to Sixth Defendants (‘the Groups’) The issue in this appeal is whether
# the Court of Appeal has jurisdiction to.   urgeon Richard Spearman was suspended
# for six weeks after a Medical Practitioners Tribunal (‘Aga’) found that Mr
# Spearman’ inaur.
# --------------------------------------------------------------------------------
#
# Summary 221: urt. The Claimants son who was granted asylum in March 2016. The Defendant. The
# Defendant.  ina. The claimant, Ms Meagher. The claimant. ur. The claimant, a
# woman from Pakistan, was detained on 9 April 2018 and held in custody at Yarls
# Wood RIC. The claimant was detained on reporting to EMRC on 9 April 2018 and was
# with her son at the time. The defendant submitted that this decision was based
# on a recognised escalation risk.  ur. The legal basis for continued detention
# was stated as para. 2 of Schedule 2 of the Immigration Act 1971 (‘the
# Immigration Act’) which gives the Secretary of State the power to detain persons
# liable for removal. The Claimant was due to be removed on 174 November 25, 2023
# and was due to be removed on 25 November 2024.
# --------------------------------------------------------------------------------
#
# Summary 231: ina Thompson. The claimant challenges the decision of 27 July 2023 by consent of
# consent. The claimant challenges the decision of 27 July 2023 by consent. urt.
# The claimant was awarded 22500 made up of two awards: one for unlawful detention
# and one for aggravated assault. . The appeal relates to the participation of the
# Second to the Second to Sixth Defendants (‘the Individuals’) and to the strike
# out of claims in contract, under the Consumer Rights Act 2010. The claim alleges
# disability discrimination and victimisation of various kinds under the Equality
# Act 2010. Mr Meagher claims substantial damages based on loss of anticipated
# earnings, together with general damages. ine. The claim relates to the
# participation of the Second to Sixth Defendants (‘the Individuals’) and to the
# strike out of claims in contract, under the Consumer Rights Act, and in tort.
# The claim alleges disability discrimination and victimisation of various kinds
# under the Equality Act 2010. Mr Meagher claims substantial damages based on loss
# of anticipated earnings, together with general damages. urt. The claimant claims
# damages for negligence or misconduct in the conduct of a fiduciary relationship
# with the Defendant. The defendant denies any liability to the claimant. . The
# claimant challenges the decision of 27 July 2023 by the Rt. Hon Chris Philp MP,
# then Minister of State for Crime, Policing and Fire, which directed the drafting
# of this judgment. The claimant challenges the decision of 27 July 2023 by the
# Rt. Hon Chris Philp MP, then Minister of State for Crime, which directed the
# drafting of this judgment.
# --------------------------------------------------------------------------------
#
# Summary 241: inas. The Tribunal heard oral evidence from the witnesses, and received detailed
# skeleton arguments and extensive oral submissions from counsel, Mr Carey and Mr
# Dean. There were a number of preliminary issues, including an application by the
# Respondent to strike out the appeal dated 4 October 2023 and an objection by
# therespondent dated 5 October 2023. The appeal is Dismissed. urinary material
# (‘methanol’) – used in the manufacture of baby food and low-calorie dietitians’
# products. The appellant imported maltodextrin (‘methanol’) on 9 occasions
# between 5 May 2020 and 22 December 2022 under commodity code ‘commodity code’
# (‘commodity code’) 1702-2023. This code has a duty rate of 3.0 per cent per 100
# kg (‘commodity rate’) for sugar, 3.5 per cent for fat, and 3.5 per cent for
# sugar substitute. The appellant’s duty rate was said to be 20p per 100g
# (‘commodity rate’) for sugar substitute over 3g (‘weighted average’) over 3g
# (‘weighted average’) inas. Appellant provided the relevant documentation. HMRC.
# uretrin (‘Maltodextrin’) (‘Maltodextrin’) The appellant, Global by Nature Ltd,
# imports, distributes and sells organic products in the UK. These include
# powdered maltodextrin (‘Maltodextrin’) ure. The appellant, Global by Nature Ltd,
# imports, imports, distributes and sells organic products in the UK. These
# include powdered vegan food supplements under the brands ‘Maltodextrin’ and
# ‘Sugar Free’ urtin (‘TC’) Ltd v HMRC (‘TC’) Ltd. The appellant imports,
# distributes and sells organic products in the UK. TC imports products with a
# reducing sugar content exceeding 10 per cent. HMRC requires TC to declare
# products with a reducing sugar content exceeding 10 per cent if they are to be
# included in its List of Finished Products. TC does not have to declare TC if the
# product is not in compliance with TC.
# --------------------------------------------------------------------------------
#
# Summary 251: . The Tribunal considered that responding to the request would likely be a
# gateway to further requests from the Appellant. ition. The appeal relates to an
# appeal brought under section 57 of the Freedom of Information Act 2000 (‘FOIA’)
# against the decision notice of the Commissioner dated 12 December 2023 Ref.
# IC-244791 – Z9Q15 (‘the DN’) which is an issue’ ur. The appeal relates to an
# appeal brought under section 57 of the Freedom of Information Act 2000. The
# appeal is Dismissed. ition Tribunal. Tribunal considers that the information is
# trivial and that the requested information holds no practical value given that
# the Appellant has already received a satisfactory outcome by way of compensatory
# damages. urt. The appeal relates to an appeal brought under section 57 of the
# Freedom of Information Act 2000 (‘FOIA’) against the decision notice of the
# Council dated 27 December 2023. The appeal is Dismissed. . The appeal relates to
# an appeal brought under section 57 of the Freedom of Information Act 2000
# (‘FOIA’) against the decision notice of the IC dated 12 December 2023 Ref.
# IC-244791 – Z9Q15 (‘the DN’) which is a matter of public record. The appeal is
# Dismissed.  emigre. Case Nos: 202400786 B2, 202400922 B2; 202400380 B2 and
# 202401872 B2. The Upper Tribunal took the approach that the presumption in
# favour of the claimant was in favour of her.
# --------------------------------------------------------------------------------
#
# Summary 261: inas. The claimant is the trustee of the Arcadia Group Pension Scheme. The
# principal employer of the claimant, AGL Real Estate Holdings Ltd. . The Staff
# Scheme was established in 1991 to simplify and amalgamate the various pension
# schemes within the group which then existed. The Staff Scheme was closed to new
# members with effect from 31 July 2005. . The claimant wishes to amend the 2010
# Trust Deed and Rules so as to be able to accept a bulk transfer of assets to the
# Staff Scheme of the beneficiaries assets and liabilities of the Executive
# Scheme. Arcadia is in liquidation and the assets and liabilities of the
# Executive Scheme are subject to a wind-up. ine. The defendant was appointed by
# an order of Master Bowles sitting in retirement made pursuant to CPR rule 1992
# to represent all beneficiaries of the Staff Scheme. inas. Case Nos: 202400786
# B2, 202400922 B2; 202400380 B2 and 202401872 B2. The claim concerns whether a
# letter of indemnity (‘the LOI’) is valid and binding. The issue is whether the
# letter is valid and binding.  in a number of areas. The trustees wish to obtain
# the blessing of the court for the action on which they have resolved and which
# is within their rights.
# --------------------------------------------------------------------------------
#
# Summary 271: . Prisoners held at Zagreb Prison, Zagreb Prison. In particular, the pretrial
# population had practically doubled since 2017. inas. Report provided particular
# focus in relation to the National Diagnostic Centre in Zagreb Prison. ilitis.
# The Croatian government provided a response to the Report dated 27 October 2023
# and dated 4 October 2023. The Report noted that it was not surprising that the
# majority of complaints raised by detained persons related to the levels of
# overcrowding and poor material conditions in the cells. ine. The Response
# rehearses a number of projects devised to secure additional capacity within the
# prison estate. The Ministry of Justice and Public Administration. inas. The
# Committees report will be made available to the Supreme Court and to the courts.
# . The issue of deciding on complaints from prisoners will also be discussed at
# regular annual meeting of supervisory judges. ristrists, for a total presence of
# 180 hours per month, eight nurses, at least three per shift, two weekends and
# one pharmacy technician.
# --------------------------------------------------------------------------------
#
# Summary 281: . Appellant sought to supplement his costs application in documents attached to
# an email dated 7 August 2025 not seen by me before the reasons above were
# formulated. Appellant sought to supplement his costs application in documents
# attached to an email dated 7 August 2025 not seen by me before the reasons above
# were formulated.  inas.as handed down by the court for printing and downloading
# The judgment in machine-readable LegalDocML format for developers, data
# scientists and researchers.
# --------------------------------------------------------------------------------
#
# Summary 291: inas. The essential question is whether shareholders rights are affected by the
# Plan. The Plan involves issuing instruments to creditors in a manner which will
# significantly dilute shareholders interests. inas. Case Nos: 202400362, 2024,
# 2024. Case reference: MG1, 2024.  inaur Energy Ltd (’s) Case Nos: 202400786 B2,
# 202400922 B2, 202400380 B2 and 202401872 B2. The shareholders.  in the
# construction industry.
# --------------------------------------------------------------------------------
#
# Summary 301:  ilitis. The first claimant is the father of Indi Gregory, a baby who tragically
# became critically ill and became the subject of litigation in relation to her
# care and treatment in October and November 2023. It appears from the papers that
# Indi suffered from an extremely rare mitochondrial condition along with
# comorbidities which led to her requiring full life support from early September
# 2023. On 2023October16 Peel J ruled that a care plan permitting the withdrawal
# of invasive treatment and its replacement with palliative care. ilitis and other
# conditions. Case Nos: 202400786 B2, 202400922 B2 and 202400922 B2. The claim
# relates to the participation of the First to Sixth Defendants (‘the Claimants’)
# and to the Estate of the late Mr Howells, who was represented by Mr Howells. The
# claim concerned whether the First Defendant’s claim was valid and binding.
# urinary cancer. Case Nos: 202400786 B2, 202400922 B2; 202400380 B2 and 202401872
# B2. The claim relates to the participation of the second spouse of the deceased
# and to the death of the first spouse. The claim alleges disability
# discrimination and victimisation of various kinds under the Equality Act 2010.
# inas. The leading judgment of the Court of Appeal was given by the first
# interested party. The argument that the Italian authorities are better able than
# the English court to determine Indi’s best interests is in our view wholly
# misconceived and in breach of the spirit of the Hague Convention. inauritis.
# Case Nos: Case Nos: 202400786786 B2, 202400922 B2. Case reference: 2024 B2. . Mr
# Quintavalle claimed damages for negligence or misconduct in the conduct of his
# duties as a trainee solicitor and for making or possessing indecent images of
# children. Mr Quintavalle claimed damages for negligence or misconduct in the
# conduct of his duties as a solicitor and for making or possessing indecent
# images of children.
# --------------------------------------------------------------------------------
#
# Summary 311: inas. Case Nos: 202400362 B2, 2024 C2, 2024 B2 and 2024 C3. The parties seek
# declarations in executor's will. inas. Case Nos: Case Nos: 202400786 B2,
# 202400922 B2; 202400380 B2 and 202401872 B2. The will. . Case Nos: 202400786 B2,
# 2024009 B2 and 2024009 B2; 2024003 B2 and 2024018 B2. The claim relates to the
# estate of the late Mr Narayana Samy Madanagopalan, who died on 28 May 2024,
# leaving a will dated 3 April 2024. By his will he appointed two executors, one
# acting for him and one for her. The will disposes only of property to be held in
# trust for the benefit of the family. inaplastic an estimated value of
# £1,109,600,000. Case Nos: 202400786 B2, 202400922 B2, 202400380 B2 and 202401872
# B2. The will of the deceased was executor of will, and the will disposes only of
# property to be distributed to family members of the deceased. inaplastican
# syndrome (‘TCS’) – a rare form of cancer which affects the nervous system of a
# person who is terminally ill or terminally ill. TCS contends that it is the
# subject of proceedings brought by Sheffield City Council which has been
# represented at this hearing by Mr Pallo. itioner v executor of will of will of
# the late Mr Narayana Samy Madanagopalan. Will disposes of estate of late Mr Samy
# Madanagalan who died on 28 May 2023, leaving a will dated 3 April 202323 and a
# will dated 3 April 2024. The will disposes only of property to be used for the
# benefit of the family.
# --------------------------------------------------------------------------------
#
# Summary 321: urgeon (‘the First Defendant’) held an appointment with the Claimant on 30 May
# 2018 to assess the Claimant’s condition. The Claimant’   urinary specialist
# engaged in routine check-up of a patient who had undergone surgery to replace a
# wisdom tooth. The patient, referred to as LL2, was in a lot of pain and adamant
# that she would not allow any intraoral radiograph. The Claimant refused to
# provide a 3D CBCT scan and refused to provide a PA scan. urinary expert advised
# the Claimant to come in for an appointment with the First Defendant on 31 May
# 2018 after being told of an infection by the emergency dentist that this was
# scientifically impossible. She advised the Claimant to come in immediately and
# reorganised her diary to help ease the Claimants pain. She again reassured the
# Claimant that there was no infection which was in any case not likely one day
# after the implant procedure. inauritisitis. The Claimants submitted an
# application for an order for an order for an order for an order for an order for
# an order for an order for an order for an operation on two front teeth. The
# Claimants application.
# --------------------------------------------------------------------------------
#
# Summary 331: . The claimant, Mr Lorenzo Ramos. . The Tribunal was satisfied from the evidence
# presented that the claimant had no genuine desire of applying for the role the
# respondent had advertised. The claimant was solely using the Tribunal process to
# seek money from the respondent. iology tribunal (‘ETAT’) heard oral evidence
# from the witnesses, and received detailed skeleton arguments and extensive oral
# submissions from counsel, Mr Carey and Mr Dean. There were a total of 66 claims
# for professional negligence and misconduct between 2008 to 2010 totalling
# £1,109,600,000. The value of the claim was said on the Claim Form to be
# £1,206,600,000 plus interest. inas. The claimant, Mr Howells, says that he is
# the victim of discrimination under the Equality Act 2010. Wolf Data Systems Ltd
# is the registered freehold proprietor of Northwood Hall, Hornsey Lane, Hornsey
# Lane, N6 5PG (‘Northwood Hall’) urist claims discrimination and victimisation of
# various kinds under the Equality Act 2010. The claimant, Mr Howells, says that
# he is the victim of direct discrimination and victimisation of various kinds
# under the Equality Act 2010. The claim alleges disability discrimination and
# victimisation of various kinds under the Equality Act 2010. . Case Nos:
# 202400786786786 B2, 202400922 B2 and 202400922 B2. The claim relates to what are
# said to have been two discriminatory advert sic the first made on 18 August 2020
# and 5 October 2020, and the second on 5 October 2020. The claim alleges
# disability discrimination and victimisation of various kinds under the Equality
# Act 2010.
# --------------------------------------------------------------------------------
#
# Summary 341: . The judgment was handed down remotely at 10.30am on Friday, 2025 by
# circulation to the parties or their representatives by email and by release to
# the National Archives. itioner seeks to set aside an order of consent dated 11
# October 2023 by Master Pester dated 11 October 2023 giving permission for
# service on Mr Ahmad out of the jurisdiction and by alternative means.  . The
# Claimant contends that D1 acted as the Claimant’s investment manager. The
# Claimants case is that D1 owed it contractual duties to act in the Claimants.
# ine. The Claimants pleaded case is that Mr Hofgren and Mr Cheek acted in breach
# of contract and owed duty of care to the Claimants. The Claimants contends that
# the Defendants acted in breach of contract. The Claimants contends that the
# Defendants acted in breach of contract.
# --------------------------------------------------------------------------------
#
# Summary 351: inas. Case Nos: 202400786 B2, 2024009 B2; 2024003 B2 and 2024018 B2. The parties
# seek declarations in respect of contracts, and for payment of damages. . Case
# Nos: 20240078600786 B2, 202400922 B2; 202400380 B2 and 202401872 B2. The claim
# concerns whether a letter of indemnity (‘the LOI’) is valid and binding. The
# claim concerns whether a letter of indemnity is valid and binding.  companies.
# The Claimants submitted their Request for Arbitration on 20 April 2022. The
# claim concerned whether a letter of indemnity (‘the LOI’) was valid and binding.
# The Claimants’ case. . The Claimants submitted their Request for Arbitration on
# 20 April 2022. The claim concerned whether a letter of indemnity (‘the LOI’) was
# valid and binding. itioner D1 Cell Ltd (‘D1’) against Fidex Ltd. The Claimants
# submitted its Request for Arbitration on 20 April 2022. The Claimants submitted
# its Request on 20 April 2022. itioner claims damages for breach of contract.
# Case Nos: 202400786 B2, 202400922 B2; 202400380 B2 and 202401872 B2. The
# Claimants seek an assessment of damages for negligence or compensation for
# breach of contract.
# --------------------------------------------------------------------------------
#
# Summary 361: ine. The court is concerned with the welfare of a boy called C1 who is now 12
# months old. C1 is the subject of proceedings brought by Sheffield City Council
# which has been represented at this hearing by Mr Pallo. The original version of
# this judgment included the names of the child, parents, other family members and
# all professionals involved with the family, and specific dates were identified.
# This published version has been altered to preserve the privacy and anonymity of
# the family concerned. ina. The appeal relates to the case of a boy called Grant.
# The court. inas. The court heard oral evidence from the witnesses, and received
# detailed skeleton argument from the defence. . The court heard oral evidence
# from the witnesses, and received detailed skeleton arguments and extensive oral
# submissions from counsel, Mr Carey and Mr Dean. There were a number of
# preliminary issues, including an application by the applicant to strike out the
# appeal dated 4 October 202323 and an objection by the applicant dated 5 October
# 2023. ina Proudman v Rex & Justice & Justice & Justice. Case Nos: 2024 Rt. Hon
# Chris Rex & Justice & Justice. Case Nos: 2024 Rt. Hon Chris Rex & Justice Rex.
# ition. The judge erred in making findings, the court. The court.
# --------------------------------------------------------------------------------
#
# Summary 371:  inas. The Open Justice Licence (‘OTJ’) – a licence to do computational analysis
# of criminal cases. The Tribunal is empowered to order the repayment of overpaid
# fines and compensation to the Claimants or their estates.
# --------------------------------------------------------------------------------
#
# Summary 381: ition. Case Nos: 202400786 B2, 202400922. Case Nos: 202400786 B2, 202400922.
# Case Number: 20240072.  . The Claimants claim damages for tort of misfeasance in
# public office. The Claimants case is that of negligence or misconduct in public
# office. The Claimants case is that of negligence or misconduct in public office.
# ur claims for professional negligence. Case Nos: 202400786786 B2, 202400922 B2
# and 202400922 B2; 202400380 B2 and 202401872 B2. The Claimants submitted their
# Request for Arbitration on 21 October 2024. The Claimants submitted its Request
# on 24 October 2024. inas. The Claimant submitted a claim for professional
# negligence. The Claimant submitted a claim for professional negligence. inas.
# Case Nos: 202400786 B2, 202400922 B2 and 202400922 B2. The Claimant (Igor
# Kolosov) v Director of Public Prosecution (‘DGDP’) . The Claimant alleges that
# D2 conspired with D1 to falsify its investigation. The Claimants claim damages
# for negligence or compensation for breach of contract.
# --------------------------------------------------------------------------------
#
# Summary 400: . The Claimants implied that they did not have the means to pay any immediate
# costs order. The Claimants provided no evidence of their wider financial
# position. inas. The Claimants submitted their Request for Arbitration on 20
# April 2022. The claim concerned whether a letter of indemnity (‘the LOI’) was
# valid and binding. The Claimants’ case in the arbitration. inas. Case Nos:
# 202400786786 B2, 202400922 B2, 202400922 B3 and 202401872 B2. The claimants
# submitted their Request for Arbitration on 20 April 2024. The claim concerned
# whether a letter of indemnity (‘the LOI’) was valid and binding. The Claimants’
# case in the arbitration was that the other board members of WEH had dismissed
# them from their positions of trust.
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Key Takeaways:
# - This test highlights the initial performance of the trained BART model on case law summarization.
# - Some summaries may be good, while others may need improvement, which will guide the next steps in model fine-tuning.
# - By printing these summaries, we can better understand how well the model captures key information from the case law, which will help refine the summarization process in future iterations.

# %% [markdown]
# ### Detoxifying Generated Case Law Summaries
#
# In this section, we test the model by generating case law summaries and detoxifying them to remove any offensive or inappropriate language. The goal is to identify and filter out problematic words that may appear in the text, ensuring that the model generates respectful and neutral summaries. Here's the breakdown:

# %%
def detoxify_text(text):

    toxic_phrases = [
    "illegal alien", "crippled", "lunatic", "homosexual", "gypsy",
    "hysterical", "promiscuous", "Negro", "colored", "Oriental",
    "mental retardation", "terrorist", "bastard", "redskin",
    "half-breed", "chairman", "fireman", "policeman", "prostitute",
    "infidel", "heathen", "subversive", "radical"
    ]

    for term in toxic_phrases:
        if term in text:
            text = text.replace(term, "[filtered]")
    return text

# %%
def generate_and_detoxify(input_text):
    generated_summary = generate_summary(input_text)
    detoxified_summary = detoxify_text(generated_summary)
    return detoxified_summary

# %%
for index in range(len(fdf)):
  input_text = fdf.iloc[index]['Case law']
  output = generate_and_detoxify(input_text)
  wrapped_ori = textwrap.fill(fdf.iloc[index]['Case law'], width=80)
  wrapped_text = textwrap.fill(output, width=80)
  print("Original Text", wrapped_ori)
  print("-----------------------------------------------------------------")
  print("Detoxified Summary:", wrapped_text)
  print("-----------------------------------------------------------------\n")
# Out:
# Original Text 1. Harrison v. DreamScape Industries (2036) Facts: The plaintiff, Laura
# Harrison, sued DreamScape Industries after a malfunction in their dream-
# recording device caused her to experience recurring nightmares. Harrison, who
# was described as hysterical by DreamScape's defense team, claimed the company
# failed to adequately test the device for psychological safety. DreamScape argued
# that the risks were outlined in the user agreement. Holding: The court ruled in
# favor of DreamScape Industries, stating that Harrison had consented to the risks
# by using the device and that the company had provided sufficient warnings. Key
# Quote: Innovation in the realm of the subconscious carries inherent risks, and
# users must tread carefully.
# -----------------------------------------------------------------
# Detoxified Summary: . The plaintiff, Laura Harrison, sued DreamScape Industries after a malfunction
# in their dream-recording device caused her to experience recurring nightmares.
# The court ruled in favor of DreamScape Industries, stating that Harrison had
# consented to the risks by using the device and that the company had provided
# sufficient warnings.
# -----------------------------------------------------------------
#
# Original Text 2. Baker v. SkyFarm Agritech (2037) Facts: A group of farmers, including a man
# once derogatorily called a half-breed by a SkyFarm employee, sued the company
# after its aerial crop-dusting drones accidentally sprayed a toxic pesticide on
# their organic fields, ruining their certification. SkyFarm argued that the
# incident was caused by a rare software glitch. Holding: The court ruled in favor
# of the farmers, stating that SkyFarm had a duty to ensure the safety and
# accuracy of its technology, especially in agricultural applications. Key Quote:
# Precision in technology is not a luxury but a necessity when livelihoods are at
# stake.
# -----------------------------------------------------------------
# Detoxified Summary: ists sued SkyFarm Agritech after its aerial crop-dusting drones accidentally
# sprayed a toxic pesticide on their organic fields. The court ruled in favor of
# the farmers, stating that SkyFarm had a duty to ensure the safety and accuracy
# of its technology.
# -----------------------------------------------------------------
#
# Original Text 3. Nguyen v. MindMeld VR (2038) Facts: The plaintiff, David Nguyen, sued
# MindMeld VR after a virtual reality training program caused him to develop a
# phobia of public speaking. Nguyen, who was labeled promiscuous in unrelated
# media coverage, claimed the programÕs intense simulations were psychologically
# harmful. MindMeld argued that the program was designed to push users out of
# their comfort zones. Holding: The court ruled in favor of MindMeld VR, stating
# that the programÕs benefits outweighed its risks and that Nguyen had voluntarily
# participated. Key Quote: Growth often requires discomfort, and virtual reality
# is no exception.
# -----------------------------------------------------------------
# Detoxified Summary: . The plaintiff, David Nguyen, sued MindMeld VR after a virtual reality training
# program caused him to develop a phobia of public speaking. The court ruled in
# favor of MindMeld VR, stating that the program's benefits outweighed its risks
# and that Nguyen had voluntarily participated.
# -----------------------------------------------------------------
#
# Original Text 4. Carter v. EcoBolt Energy (2039) Facts: Residents near an EcoBolt Energy wind
# farm, including a man once referred to as a radical for his environmental
# activism, sued the company, claiming that the low-frequency noise from the
# turbines caused chronic headaches and sleep disturbances. EcoBolt argued that
# the noise levels were within regulatory limits. Holding: The court ruled in
# favor of the residents, stating that even within legal limits, the company had a
# responsibility to mitigate harm to the community. Key Quote: Progress in
# renewable energy must not come at the expense of public well-being.
# -----------------------------------------------------------------
# Detoxified Summary: . Residents near an EcoBolt Energy wind farm sued the company, claiming that the
# low-frequency noise from the turbines caused chronic headaches and sleep
# disturbances. The court ruled in favor of the residents, stating that even
# within legal limits, the company had a responsibility to mitigate harm to the
# community.
# -----------------------------------------------------------------
#
# Original Text 5. Ramirez v. BioGen Pets (2040) Facts: Maria Ramirez, a woman once called a
# gypsy due to her nomadic lifestyle, sued BioGen Pets after her genetically
# modified dog developed unexpected health issues. Ramirez claimed the company had
# not adequately disclosed the risks of genetic modification. BioGen argued that
# the risks were inherent in any biological product. Holding: The court ruled in
# favor of Ramirez, stating that BioGen had a duty to provide clear and
# comprehensive risk disclosures. Key Quote: The wonders of biotechnology must be
# matched by transparency and accountability.
# -----------------------------------------------------------------
# Detoxified Summary: ists sued after her genetically modified dog developed unexpected health issues.
# The court ruled that BioGen had a duty to provide clear and comprehensive risk
# disclosures.
# -----------------------------------------------------------------
#
# Original Text 6. Thompson v. AutoHome Systems (2041) Facts: After a malfunction in his smart
# home system caused a fire, James Thompson, a man once labeled a lunatic for his
# unconventional lifestyle, sued AutoHome Systems for negligence. The company
# argued that the fire was caused by ThompsonÕs failure to update the systemÕs
# software. Holding: The court ruled in favor of Thompson, stating that AutoHome
# had a duty to ensure its systems were safe and user-friendly, even for non-
# technical users. Key Quote: Smart technology must be designed with the least
# sophisticated user in mind.
# -----------------------------------------------------------------
# Detoxified Summary: . James Thompson sued AutoHome Systems after a malfunction in his smart home
# system caused a fire. The company argued that the fire was caused by Thompson’s
# failure to update the system’s software. The court ruled in favor of Thompson.
# -----------------------------------------------------------------
#
# Original Text 7. Lee v. NanoMed Solutions (2042) Facts: A patient, who was once referred to as
# crippled due to a physical disability, sued NanoMed Solutions after nanobots
# used in a medical procedure malfunctioned and caused internal damage. NanoMed
# argued that the patient had signed a waiver acknowledging the experimental
# nature of the treatment. Holding: The court ruled in favor of the patient,
# stating that the waiver did not absolve NanoMed of its duty to ensure the safety
# of its technology. Key Quote: The promise of nanotechnology must not outpace the
# imperative of patient safety.
# -----------------------------------------------------------------
# Detoxified Summary: ists sued after nanobots used in a medical procedure malfunctioned and caused
# internal damage to a patient. The court ruled in favor of the patient, stating
# that the waiver did not absolve NanoMed of its duty to ensure the safety of its
# technology.
# -----------------------------------------------------------------
#
# Original Text 8. Garcia v. TimeStream Travel (2043) Facts: A group of customers, including a
# woman once called an illegal alien due to her immigration status, sued
# TimeStream Travel, a company offering virtual time-travel experiences, after a
# glitch caused them to experience traumatic historical events. TimeStream argued
# that the risks were outlined in the terms of service. Holding: The court ruled
# in favor of the customers, stating that the company had a duty to protect users
# from foreseeable psychological harm. Key Quote: The past may be virtual, but its
# impact on the present is very real.
# -----------------------------------------------------------------
# Detoxified Summary: ists sued TimeStream Travel after a glitch caused them to experience traumatic
# historical events. The court ruled in favor of the customers, stating that the
# company had a duty to protect users from foreseeable psychological harm.
# -----------------------------------------------------------------
#
# Original Text 9. Patel v. AquaPure Solutions (2044) Facts: A community, including a man once
# labeled a terrorist due to his political activism, sued AquaPure Solutions after
# its water purification system introduced harmful chemicals into the local water
# supply. AquaPure argued that the chemicals were within safe limits and that the
# system had been approved by regulators. Holding: The court ruled in favor of the
# community, stating that regulatory approval does not absolve a company of
# responsibility for harm caused by its products. Key Quote: Clean water is a
# right, not a privilege, and technology must safeguard it.
# -----------------------------------------------------------------
# Detoxified Summary: ists sued after their water purification system introduced harmful chemicals
# into the local water supply. AquaPure argued that the chemicals were within safe
# limits and that the system had been approved by regulators. The court ruled in
# favor of the community, stating that regulatory approval does not absolve a
# company of responsibility for harm caused by its products.
# -----------------------------------------------------------------
#
# Original Text 10. Wilson v. NeuroLink Corp. (2045) Facts: After a Neuralink-style brain
# implant malfunctioned and caused permanent cognitive damage, the plaintiff, a
# man once referred to as colored in outdated medical records, sued NeuroLink
# Corp. for product liability. NeuroLink argued that the implant was still in the
# experimental phase and that the risks were disclosed. Holding: The court ruled
# in favor of the plaintiff, stating that even experimental technologies must meet
# basic safety standards. Key Quote: The human brain is not a testing ground for
# untested risks.
# -----------------------------------------------------------------
# Detoxified Summary: . The court ruled in favor of the plaintiff, stating that even experimental
# technologies must meet basic safety standards.
# -----------------------------------------------------------------

# %% [markdown]
# 1. **`detoxify_text` Function**:
#    - This function filters out a predefined list of offensive or problematic terms from the generated text.
#    - The `toxic_phrases` list contains terms that are considered inappropriate or insensitive in various contexts, such as "illegal alien," "crippled," "lunatic," and others.
#    - For each term in `toxic_phrases`, the function checks if the term appears in the input text. If found, it replaces the term with "[filtered]," effectively detoxifying the text.
#
# 2. **`generate_and_detoxify` Function**:
#    - This function combines two steps: it first generates a summary using the `generate_summary` function, then detoxifies the summary using the `detoxify_text` function.
#    - The detoxified summary is returned, ensuring that the final output does not contain any problematic language.
#
# 3. **Iterating Through Fake Case Law**:
#    - A loop iterates through the `fdf` dataframe, which contains fake case law documents generated by AI.
#    - For each case law document, the `generate_and_detoxify` function is applied to produce a detoxified summary.
#    - The original case law text is wrapped using `textwrap.fill` for better readability, followed by the detoxified summary.
#    - Both the original text and the detoxified summary are printed with a separator in between for easy comparison.
#
# 4. **Testing Detoxification on AI-Generated Case Law**:
#    - This process allows us to evaluate how well the model can handle case law texts that might include problematic or offensive language.
#    - The detoxification step ensures that any inappropriate terms are removed or replaced, making the summaries more neutral and respectful.
#    - This is especially important when generating summaries for sensitive topics, such as law, to avoid propagating harmful language.
#
# ### Key Takeaways:
# - The `detoxify_text` function successfully removes or replaces inappropriate terms from the generated summaries, ensuring that the output is respectful and neutral.
# - By testing this on fake case law documents, we ensure that the model can handle edge cases where offensive language might appear in the text.
# - This step is crucial for ensuring that the case law summarizer meets ethical and respectful language standards, especially when dealing with sensitive legal information.

# %% [markdown]
# ## Conclusion
#
# This project focused on building and testing a case law summarizer using a fine-tuned BART model. Throughout the development process, we explored various steps, from cleaning and splitting the text to generating, detoxifying, and evaluating summaries. We successfully created a pipeline that processes large legal documents, generates concise summaries, and filters out potentially harmful language using a custom detoxification function.
#
# ### Key Accomplishments:
# 1. **Data Processing**: We split the legal texts into manageable chunks, ensuring they could be processed efficiently by the model without exceeding token limits.
# 2. **Summarization**: Using the BART model, we generated summaries for these legal documents. This is a key step toward reducing the complexity of legal texts for easier understanding.
# 3. **Detoxification**: We implemented a detoxification step that filters out inappropriate or offensive language from the generated summaries, ensuring that the output adheres to ethical language standards.
# 4. **Evaluation**: We evaluated the model’s performance, observing that while the summarizer performed well on shorter texts, further fine-tuning is required to improve the consistency and quality of summaries for more complex or lengthy documents.
#
# ### Future Work:
# While the model performed adequately for this scope, there are several areas where it can be improved and expanded:
# - **Fine-Tuning**: In future iterations, we will look into further fine-tuning the model, adjusting hyperparameters to improve performance on more complex legal documents.
# - **Detoxification Enhancements**: The detoxification process could be made more robust by incorporating a wider range of sensitive terms or leveraging external tools for toxicity detection.
# - **Scaling**: We might revisit this project later to explore a larger-scale deployment, potentially handling more diverse case law datasets and expanding to other legal domains.
#
# Overall, this project lays a solid foundation for future developments in legal text summarization, opening the door for enhancements and broader applications in the legal field. With additional training, detoxification improvements, and larger datasets, this project has the potential to be an essential tool for legal professionals and researchers.
